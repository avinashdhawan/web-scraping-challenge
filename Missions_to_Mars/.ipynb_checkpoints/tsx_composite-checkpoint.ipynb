# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine
from splinter import Browser
from bs4 import BeautifulSoup
import psycopg2

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# URL of page to be scraped
url = 'https://www.theglobeandmail.com/investing/markets/indices/TXSX/components/'
browser.visit(url)
import time
time.sleep(10)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
browser.find_by_id('dataTableDropdownSelect').select_by_text('Main View')
time.sleep(3)
html = browser.html

# %%
main_table = pd.read_html(html)[0]
main_table.head(3)
# Out:
#    Symbol                   Name    Last          Change        % Change  \
# 0    RY-T   Royal Bank of Canada   84.48   -1.15decrease  -1.34%decrease
# 1    TD-T  Toronto-Dominion Bank   57.04   -1.12decrease  -1.93%decrease
# 2  SHOP-T            Shopify Inc  863.14  -19.64decrease  -2.22%decrease
#
#      Open    High     Low      Time
# 0   84.50   84.85   84.00  05/01/20
# 1   57.65   57.65   56.65  05/01/20
# 2  862.04  879.10  840.01  05/01/20

# %%
browser.find_by_id('dataTableDropdownSelect').select_by_text('Performance')
time.sleep(3)
html = browser.html

# %%
perf_table = pd.read_html(html)[0]
perf_table.head(3)
# Out:
#    Symbol                   Name    Last      YTD %Change  1-Month %Change  \
# 0    RY-T   Royal Bank of Canada   84.48  -17.78%decrease   +1.72%increase
# 1    TD-T  Toronto-Dominion Bank   57.04  -21.68%decrease   +0.42%increase
# 2  SHOP-T            Shopify Inc  863.14  +67.18%increase  +58.02%increase
#
#    3-Month %Change   52-Week %Change  52-Week High  52-Week Low
# 0  -19.22%decrease   -20.64%decrease        109.68        72.00
# 1  -22.01%decrease   -25.15%decrease         77.96        49.01
# 2  +40.05%increase  +160.77%increase        945.36       326.69

# %%
combined_table = pd.merge(main_table, perf_table, on = ("Symbol", "Name", "Last"))
combined_table
# Out:
#       Symbol                                     Name     Last  \
# 0       RY-T                     Royal Bank of Canada    84.48
# 1       TD-T                    Toronto-Dominion Bank    57.04
# 2     SHOP-T                              Shopify Inc   863.14
# 3      ENB-T                             Enbridge Inc    42.01
# 4      CNR-T            Canadian National Railway Co.   113.22
# 5    BAM-A-T  Brookfield Asset Management Inc Cl.A Lv    46.14
# 6      BNS-T                      Bank of Nova Scotia    54.25
# 7      ABX-T                        Barrick Gold Corp    37.87
# 8      TRP-T                           Tc Energy Corp    63.00
# 9      BCE-T                                  BCE Inc    55.61
# 10     TRI-T                     Thomson Reuters Corp    97.24
# 11     BMO-T                         Bank of Montreal    68.55
# 12   ATD-B-T     Alimentation Couche-Tard Inc Cl B Sv    39.59
# 13      CP-T         Canadian Pacific Railway Limited   311.90
# 14      SU-T                        Suncor Energy Inc    24.14
# 15      CM-T       Canadian Imperial Bank of Commerce    81.00
# 16     FNV-T                       Franco-Nevada Corp   194.52
# 17     MFC-T                             Manulife Fin    16.90
# 18     WCN-T                    Waste Connections Inc   118.11
# 19   RCI-B-T        Rogers Communications Inc Cl.B NV    57.94
# 20       T-T                               Telus Corp    22.52
# 21     CSU-T               Constellation Software Inc  1350.75
# 22     NTR-T                              Nutrien Ltd    48.76
# 25         59.28        41.52
# 26         77.00        59.01
# 27        114.49        67.23
# 28         58.03        26.50
# 29        105.93        36.48
# 30         86.86        43.25
# 31         75.01        38.67
# 32         53.79        15.27
# 33         38.96        10.27
# 34         75.25        33.22
# 35         74.66        37.45
# 36         67.87        25.67
# 37         35.15        17.47
# 38        113.94        84.01
# 39         61.74        47.88
# 40         46.26        29.31
# 41         63.43        42.30
# 42         52.12        34.70
# 43         60.94        42.12
# 44         28.35        10.05
# 45         27.91        17.77
# 46         10.19         4.00
# 47         42.15        16.30
# 48         68.49        34.57
# 49         68.19        12.96
# 50         30.90         8.15
# 51        157.36        67.15
# 52         14.31         2.06
# 53         14.10         4.71
# 54         14.78         7.69
# 55         25.42         5.35
# 56         34.36        15.47
# 57         53.33        13.64
# 58         12.62         3.94
# 59          2.46         0.38

# %%
rds_connection_string = "postgres:postgres@localhost:5432/tsx-composite"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['combined_table', 'combined_table1', 'new_table']

# %%
# new_table = combined_table

# %%
combined_table.columns
# Out:
# Index(['Symbol', 'Name', 'Last', 'Change', '% Change', 'Open', 'High', 'Low',
#        'Time', 'YTD %Change', '1-Month %Change', '3-Month %Change',
#        '52-Week %Change', '52-Week High', '52-Week Low'],
#       dtype='object')

# %%
combined_table.columns = [
    'Symbol', 'Name', 'Last', 'Change', "pct_change", 'Open', 'High', 'Low',
       'Time', 'YTD pct_change', '1_Month pct_change', '3_Month pct_change',
       '52_Week pct_change', '52_Week High', '52_Week Low'
]

# %%
combined_table.to_sql(name='combined_table', con=engine, if_exists='replace', index=False)

# %%
pd.read_sql_query('select * from combined_table', con=engine).head()
# Out:
#    Symbol                           Name    Last          Change  \
# 0    RY-T           Royal Bank of Canada   84.48   -1.15decrease
# 1    TD-T          Toronto-Dominion Bank   57.04   -1.12decrease
# 2  SHOP-T                    Shopify Inc  863.14  -19.64decrease
# 3   ENB-T                   Enbridge Inc   42.01   -0.64decrease
# 4   CNR-T  Canadian National Railway Co.  113.22   -1.89decrease
#
#        pct_change    Open    High     Low      Time   YTD pct_change  \
# 0  -1.34%decrease   84.50   84.85   84.00  05/01/20  -17.78%decrease
# 1  -1.93%decrease   57.65   57.65   56.65  05/01/20  -21.68%decrease
# 2  -2.22%decrease  862.04  879.10  840.01  05/01/20  +67.18%increase
# 3  -1.50%decrease   42.12   42.86   41.85  05/01/20  -18.63%decrease
# 4  -1.64%decrease  114.58  114.97  113.03  05/01/20   -3.62%decrease
#
#   1_Month pct_change 3_Month pct_change 52_Week pct_change  52_Week High  \
# 0     +1.72%increase    -19.22%decrease    -20.64%decrease        109.68
# 1     +0.42%increase    -22.01%decrease    -25.15%decrease         77.96
# 2    +58.02%increase    +40.05%increase   +160.77%increase        945.36
# 3     +8.75%increase    -21.93%decrease    -15.20%decrease         57.32
# 4     +6.36%increase     -8.45%decrease     -8.53%decrease        127.96
#
#    52_Week Low
# 0        72.00
# 1        49.01
# 2       326.69
# 3        33.06
# 4        92.01
